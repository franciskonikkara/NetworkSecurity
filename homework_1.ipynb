# %%
import numpy as np

UID = 1234                                        #Your UID should be included in your program as a global variable
Last_Name = 'Your Last Name'                      #Your Last Name should be included in your program as a global variable
First_Name = 'Your First Name'                    #Your First Name should be included in your program as a global variable

def caesar_str_enc(plaintext, k):                 #Your encryption function should have the same name and must accept a string as the first argument and an integer as a second argument
	'''
    Your
    Code
    Here
    '''
	return ciphertext                             #Your function must return a string

def caesar_str_dec(ciphertext, k):                #Your decryption function should have the same name and must accept a string as the first argument and an integer as a second argument
	'''
    Your
    Code
    Here
    '''
	return plaintext                              #Your function must return a string

def vigenere_enc(keyword, plaintext):

  # plaintext is the plaintext string of arbitrary length
  # Both strings will be from {a,b,...,z,A,B,...,Z} and you need to convert to upper case

  # perform the encryption of given plaintext using the given keyword
  # according to the Vigenere cipher. You need to repeat the keyword
  # enough times if needed to make it the same length as plaintext

  return ciphertext

def vigenere_dec(keyword, ciphertext):

  # ciphertext is the ciphertext string of arbitrary length
  # Both strings will be from {a,b,...,z,A,B,...,Z}

  # perform the decryption of given ciphertext using the given keyword
  # according to the Vigenere cipher. You need to repeat the keyword
  # enough times if needed to make it the same length as ciphertext

  return plaintext


if __name__ == "__main__":                        #You may write your testing code to make sure above 2 functions work here.
	input_str = 'test string'
  # Part 1 - Caesar
  encstr = caesar_str_enc(input_str,k)
	print(encstr)                                 #You may use print statements to verify your own results
	decstr = caesar_str_dec(encstr, k)
	print(decstr)
  test_function()                               #You may write and call your own function

  #Part 2 - Vigenere
  input_key = 'keyword'
  encstr = vigenere_enc(input_str,input_key)
  print("Ciphertext: {encstr}")               #You may use print statements to verify your own results
  decstr = vigenere_dec(encstr,input_key)
  print("Decryptedtext: {decstr}")

def test_function():                              #You may write your own extra functions. However, we will not test anything except the required 2 functions. Make sure your functionality is within those functions.
    #Your test code here
    return None
